# %%
import csv
import re
from sklearn.externals import joblib
# tag_count = joblib.load("/media/data/hotels/kdd11/processed/extracted_tag/kdd11_tag_count.pkl")
# tag_dict = joblib.load("/media/data/hotels/kdd11/processed/extracted_tag/kdd11_tag_dict.pkl")
tag_count, tag_dict = joblib.load('/media/data/hotels/kdd11/processed/extracted_tag/kdd11_tag_count_dict_c5.pkl')

# %%
def pop_count(tag_count, tag_dict):
    print(len(tag_count), len(tag_dict))
    pos = []
    for k, v in tag_count.most_common():
        if v <= 5:
            pos.append(k)

    for k in pos:
        tag_count.pop(k)
        tag_dict.pop(k)
    print(len(tag_count), len(tag_dict))

    joblib.dump([tag_count, tag_dict], "/media/data/hotels/kdd11/processed/extracted_tag/kdd11_tag_count_dict_c5.pkl")

# %%
tag_count.most_common(200)
# Out:
# [("('DT', 'NN', 'VBD', 'JJ', '.')", 50288),
#  ("('JJ', 'NN', '.')", 41154),
#  ("('DT', 'NN', 'VBZ', 'JJ', '.')", 26655),
#  ("('DT', 'NN', 'VBD', 'RB', 'JJ', '.')", 25429),
#  ("('RB', 'JJ', '.')", 23816),
#  ("('PRP', 'MD', 'RB', 'VB', 'RB', 'RB', '.')", 20121),
#  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 19334),
#  ("('NN', 'VBD', 'JJ', '.')", 18287),
#  ("('DT', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", 16219),
#  ("('PRP', 'VBD', 'JJ', '.')", 14865),
#  ("('PRP', 'VBD', 'RB', 'JJ', '.')", 12688),
#  ("('DT', 'NN', 'VBZ', 'RB', 'JJ', '.')", 12038),
#  ("('PRP', 'VBD', 'DT', 'JJ', 'NN', '.')", 11414),
#  ("('RB', 'JJ', 'NN', '.')", 11025),
#  ("('NNP', 'NN', '.')", 10548),
#  ("('PRP', 'MD', 'VB', 'RB', 'RB', '.')", 9722),
#  ("('NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 9525),
#  ("('DT', 'NNS', 'VBD', 'JJ', '.')", 9111),
#  ("('NN', 'VBD', 'RB', 'JJ', '.')", 9045),
#  ("('RB', 'VBN', '.')", 8130),
#  ("('JJ', 'NNS', '.')", 7951),
#  ("('NNP', 'VBD', 'JJ', '.')", 7897),
#  ("('DT', 'NN', 'NN', 'VBD', 'JJ', '.')", 7830),
#  ("('DT', 'NN', '.')", 7533),
#  ("('DT', 'NNS', 'VBP', 'JJ', '.')", 7458),
#  ("('PRP', 'MD', 'VB', 'RB', '.')", 7203),
#  ("('MD', 'RB', 'VB', 'RB', 'RB', '.')", 7202),
#  ("('PRP', 'MD', 'RB', 'VB', 'RB', '.')", 7150),
#  ("('PRP', 'VBD', 'DT', 'NN', '.')", 7129),
#  ("('DT', 'JJ', 'NN', '.')", 6571),
#  ("('JJ', 'NN', 'NN', '.')", 6142),
#  ("('WP', 'DT', 'JJ', 'NN', '.')", 6084),
#  ("('PRP', 'MD', 'RB', 'VB', 'DT', 'NN', '.')", 6032),
#  ("('DT', 'NN', 'VBZ', 'JJ', 'CC', 'JJ', '.')", 5929),
#  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'RB', 'JJ', '.')", 5740),
#  ("('DT', 'NNS', 'VBD', 'RB', 'JJ', '.')", 5554),
#  ("('NN', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", 5261),
#  ("('NNP', 'VBZ', 'JJ', '.')", 4614),
#  ("('DT', 'NNS', 'VBD', 'JJ', 'CC', 'JJ', '.')", 4597),
#  ("('RB', 'DT', 'JJ', 'NN', '.')", 4585),
#  ("('JJ', 'JJ', 'NN', '.')", 4534),
#  ("('WP', 'DT', 'NN', '.')", 4523),
#  ("('DT', 'NN', 'VBZ', 'RB', 'JJ', 'CC', 'JJ', '.')", 4499),
#  ("('NN', 'VBZ', 'JJ', '.')", 4495),
#  ("('DT', 'NNS', 'VBP', 'RB', 'JJ', '.')", 4474),
#  ("('DT', 'NNS', 'VBP', 'JJ', 'CC', 'JJ', '.')", 4388),
#  ("('PRP$', 'NN', 'VBD', 'JJ', '.')", 4317),
#  ("('NNP', 'NNP', '.')", 4195),
#  ("('PRP', 'VBD', 'RB', 'VBN', '.')", 4161),
#  ("('DT', 'NN', 'IN', 'DT', 'NN', 'VBD', 'JJ', '.')", 4023),
#  ("('PRP', 'VBD', 'PRP', '.')", 3889),
#  ("('MD', 'RB', 'VB', 'RB', '.')", 3871),
#  ("('DT', 'NN', 'NN', 'VBD', 'RB', 'JJ', '.')", 3843),
#  ("('RB', 'JJ', 'CC', 'JJ', '.')", 3803),
#  ("('DT', 'NN', 'IN', 'DT', 'NN', 'VBZ', 'JJ', '.')", 3772),
#  ("('NNS', 'VBD', 'JJ', '.')", 3769),
#  ("('DT', 'NNS', '.')", 3698),
#  ("('MD', 'VB', 'RB', 'RB', '.')", 3637),
#  ("('DT', 'NN', 'NN', 'VBZ', 'JJ', '.')", 3582),
#  ("('DT', 'JJ', 'NN', 'VBD', 'JJ', '.')", 3578),
#  ("('DT', 'VBZ', 'DT', 'JJ', 'NN', '.')", 3495),
#  ("('PRP', 'RB', 'VB', 'DT', 'NN', '.')", 3456),
#  ("('NN', 'NN', 'VBD', 'JJ', '.')", 3294),
#  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'DT', 'NN', 'VBD', 'JJ', '.')", 3273),
#  ("('PRP', 'RB', 'VBD', 'DT', 'NN', '.')", 3210),
#  ("('RB', 'RB', '.')", 3172),
#  ("('JJ', 'NN', 'IN', 'DT', 'NN', '.')", 3042),
#  ("('PRP', 'VBZ', 'JJ', '.')", 3035),
#  ("('JJ', 'CC', 'JJ', '.')", 3017),
#  ("('VB', 'PRP', '.')", 2938),
#  ("('PRP', 'MD', 'RB', 'VB', '.')", 2929),
#  ("('NN', 'NN', '.')", 2924),
#  ("('PRP', 'VBP', 'DT', 'NN', '.')", 2870),
#  ("('JJ', 'NN', 'IN', 'NN', '.')", 2846),
#  ("('NNS', 'VBP', 'JJ', '.')", 2832),
#  ("('NNP', 'JJ', '.')", 2761),
#  ("('PRP', 'VBZ', 'RB', 'JJ', '.')", 2720),
#  ("('PRP', 'VBZ', 'DT', 'JJ', 'NN', '.')", 2685),
#  ("('NNP', 'NNP')", 2668),
#  ("('MD', 'RB', 'VB', '.')", 2617),
#  ("('MD', 'VB', 'RB', '.')", 2571),
#  ("('DT', 'NN', 'VBD', 'RB', 'RB', 'JJ', '.')", 2522),
#  ("('NN', 'VBZ', 'RB', 'JJ', '.')", 2520),
#  ("('RB', 'RB', 'JJ', '.')", 2516),
#  ("('DT', 'VBD', 'JJ', '.')", 2505),
#  ("('DT', 'VBD', 'DT', 'JJ', 'NN', '.')", 2498),
#  ("('PRP', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", 2480),
#  ("('MD', 'PRP', 'VB', 'RB', 'RB', '.')", 2433),
#  ("('PRP', 'VBD', 'RB', '.')", 2426),
#  ("('DT', 'NN', 'NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 2417),
#  ("('DT', 'NN', 'VBZ', 'DT', 'JJ', 'NN', '.')", 2416),
#  ("('PRP', 'VBD', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NN', '.')", 2395),
#  ("('DT', 'NN', 'VBD', 'JJ', ',', 'JJ', 'CC', 'JJ', '.')", 2362),
#  ("('PRP', 'VBD', 'JJ', 'CC', 'JJ', '.')", 2350),
#  ("('DT', 'NNS', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", 2343),
#  ("('PRP', 'VBD', 'IN', 'DT', 'JJ', 'NN', '.')", 2332),
#  ("('JJ', 'NN', 'CC', 'JJ', 'NN', '.')", 2300),
#  ("('VBD', 'PRP', '.')", 2292),
#  ("('NNP', 'NN', 'VBD', 'JJ', '.')", 2260),
#  ("('NNP', 'VBD', 'RB', 'JJ', '.')", 2226),
#  ("('RB', 'JJ', 'CC', 'JJ', 'NN', '.')", 2217),
#  ("('PRP$', 'NN', 'VBD', 'RB', 'JJ', '.')", 2217),
#  ("('PRP', 'MD', 'RB', 'VB', 'IN', 'DT', 'NN', 'RB', '.')", 2214),
#  ("('RB', 'JJ', 'NNS', '.')", 2208),
#  ("('DT', 'NN', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", 2207),
#  ("('JJ', 'CC', 'JJ', 'NN', '.')", 2202),
#  ("('PRP', 'VBD', 'RB', 'JJ', 'IN', 'DT', 'NN', '.')", 2173),
#  ("('NNS', 'VBD', 'RB', 'JJ', '.')", 2157),
#  ("('PRP', 'MD', 'RB', 'VB', 'PRP', '.')", 2153),
#  ("('DT', 'NN', 'VBD', 'DT', 'JJ', 'NN', '.')", 2136),
#  ("('PRP$', 'NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 2123),
#  ("('JJ', 'NN', 'CC', 'NN', '.')", 2100),
#  ("('NN', 'JJ', '.')", 2036),
#  ("('DT', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'RB', 'JJ', '.')", 2015),
#  ("('DT', 'NN', 'VBZ', 'IN', 'DT', 'JJ', 'NN', '.')", 2013),
#  ("('JJ', 'NN', ',', 'JJ', 'NN', '.')", 1993),
#  ("('NNS', 'VBD', 'JJ', 'CC', 'JJ', '.')", 1947),
#  ("('DT', 'NN', 'CC', 'NN', 'VBD', 'JJ', '.')", 1902),
#  ("('PRP', 'MD', 'RB', 'VB', 'TO', 'VB', 'RB', '.')", 1868),
#  ("('NNS', 'VBP', 'JJ', 'CC', 'JJ', '.')", 1867),
#  ("('DT', 'NN', 'VBD', 'JJ', 'RB', '.')", 1860),
#  ("('RB', 'VB', '.')", 1855),
#  ("('NN', 'VBZ', 'JJ', 'CC', 'JJ', '.')", 1827),
#  ("('DT', 'NN', 'NN', '.')", 1820),
#  ("('RB', 'DT', 'NN', '.')", 1804),
#  ("('DT', 'JJ', 'NN', 'VBD', 'RB', 'JJ', '.')", 1803),
#  ("('DT', 'NNS', 'VBP', 'RB', 'JJ', 'CC', 'JJ', '.')", 1792),
#  ("('PRP', 'MD', 'RB', 'VB', 'DT', 'NN', 'TO', 'NN', '.')", 1759),
#  ("('PRP', 'VBD', '.')", 1755),
#  ("('PRP', 'MD', 'VB', '.')", 1754),
#  ("('DT', 'NN', 'VBZ', 'DT', 'NN', '.')", 1751),
#  ("('DT', 'NN', 'NN', 'VBZ', 'RB', 'JJ', '.')", 1744),
#  ("('PRP', 'MD', 'VB', 'DT', 'NN', 'TO', 'NN', '.')", 1739),
#  ("('PRP', 'VBD', 'DT', 'RB', 'JJ', 'NN', '.')", 1735),
#  ("('DT', 'NN', 'VBZ', 'JJ', 'CC', 'RB', 'JJ', '.')", 1722),
#  ("('NNP', 'RB', 'JJ', '.')", 1704),
#  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'RB', 'VBN', '.')", 1679),
#  ("('DT', 'RB', 'JJ', 'NN', '.')", 1664),
#  ("('PRP', 'MD', 'VB', 'DT', 'NN', '.')", 1635),
#  ("('DT', 'NN', 'IN', 'DT', 'NN', 'VBD', 'RB', 'JJ', '.')", 1615),
#  ("('NNP', 'RB', '.')", 1584),
#  ("('DT', 'NN', 'VBD', 'DT', 'NN', '.')", 1574),
#  ("('JJ', 'NN', 'RB', '.')", 1566),
#  ("('DT', 'VBD', 'RB', 'JJ', '.')", 1549),
#  ("('DT', 'NN', 'PRP', 'VBD', 'JJ', '.')", 1548),
#  ("('NN', 'VBD', 'JJ', 'CC', 'RB', 'JJ', '.')", 1542),
#  ("('JJ', 'NN', 'IN', 'DT', 'JJ', 'NN', '.')", 1525),
#  ("('NNS', 'VBP', 'RB', 'JJ', '.')", 1518),
#  ("('PRP', 'MD', 'VB', 'RB', 'RB', 'IN', 'DT', 'NN', '.')", 1516),
#  ("('VBD', 'DT', 'JJ', 'NN', '.')", 1505),
#  ("('RB', ',', 'DT', 'JJ', 'NN', '.')", 1498),
#  ("('MD', 'RB', 'VB', 'DT', 'NN', '.')", 1485),
#  ("('PRP', 'VBD', 'DT', 'NN', 'IN', 'DT', 'NN', '.')", 1484),
#  ("('RB', 'NN', '.')", 1484),
#  ("('PRP', 'VBD', 'VBN', '.')", 1477),
#  ("('PRP', 'VBD', 'DT', 'NN', 'NN', '.')", 1472),
#  ("('MD', 'RB', 'VB', 'TO', 'VB', 'RB', '.')", 1471),
#  ("('PRP', 'VBD', 'IN', 'DT', 'NN', 'IN', 'CD', 'NNS', '.')", 1467),
#  ("('RB', 'IN', 'DT', 'NN', '.')", 1467),
#  ("('PRP', 'VBD', 'CD', 'NNS', '.')", 1465),
#  ("('VB', 'DT', 'NN', '.')", 1447),
#  ("('PRP', 'RB', 'VB', 'PRP', '.')", 1429),
#  ("('MD', 'PRP', 'VB', 'RB', '.')", 1415),
#  ("('JJ', 'NNP', '.')", 1412),
#  ("('PRP', 'VBD', 'PRP$', 'NN', '.')", 1411),
#  ("('NN', 'IN', 'NN', '.')", 1400),
#  ("('PRP', 'MD', 'RB', 'VB', 'VBN', '.')", 1378),
#  ("('IN', 'DT', 'NN', '.')", 1377),
#  ("('VB', 'IN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 1376),
#  ("('DT', 'NN', 'VBZ', 'RB', 'RB', 'JJ', '.')", 1375),
#  ("('PRP', 'RB', 'VBD', 'PRP$', 'NN', '.')", 1356),
#  ("('DT', 'NNS', 'VBP', 'JJ', 'CC', 'RB', 'JJ', '.')", 1354),
#  ("('VBD', 'DT', 'NN', '.')", 1350),
#  ("('RB', ',', 'DT', 'NN', 'VBD', 'JJ', '.')", 1333),
#  ("('DT', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'DT', 'NN', 'VBD', 'JJ', '.')", 1329),
#  ("('NNP', 'RB', 'JJ', 'CC', 'JJ', '.')", 1327),
#  ("('JJ', 'NN', 'IN')", 1305),
#  ("('RB', ',', 'PRP', 'VBD', 'DT', 'JJ', 'NN', '.')", 1293),
#  ("('DT', 'NN', 'VBP', 'RB', 'JJ', 'CC', 'JJ', '.')", 1282),
#  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'DT', 'NN', 'VBD', 'RB', 'JJ', '.')", 1282),
#  ("('DT', 'NNS', 'VBD', 'JJ', 'CC', 'RB', 'JJ', '.')", 1276),
#  ("('PRP', 'RB', 'VBD', 'PRP', '.')", 1275),
#  ("('JJ', 'NN', 'NNS', '.')", 1256),
#  ("('NNP', 'VBZ', 'RB', 'JJ', '.')", 1253),
#  ("('JJ', ',', 'JJ', 'NN', '.')", 1243),
#  ("('PRP', 'VBD', 'RB', 'RB', 'JJ', '.')", 1230),
#  ("('PRP', 'VBD', 'IN', 'DT', 'NN', '.')", 1219),
#  ("('DT', 'NN', 'VBD', 'JJ', 'NN')", 1212),
#  ("('PRP', 'VBD', 'IN', 'CD', 'NNS', '.')", 1205),
#  ("('DT', 'NN', 'VBD', 'NNP', '.')", 1198),
#  ("('RB', 'JJ', 'NN', 'NN', '.')", 1193),
#  ("('DT', 'NN', 'IN', 'DT', 'NN', 'VBZ', 'RB', 'JJ', '.')", 1189),
#  ("('RB', 'JJ', 'IN')", 1188),
#  ("('RB', 'VB', 'DT', 'NN', '.')", 1183),
#  ("('NNP', 'JJ', 'NN', '.')", 1183),
#  ("('DT', 'JJ', 'NN', 'VBZ', 'JJ', '.')", 1183),
#  ("('PRP', 'MD', 'RB', 'VB', 'TO', 'VB', 'RB', 'RB', '.')", 1179),
#  ("('DT', 'NN', 'NNS', 'VBD', 'JJ', '.')", 1177),
#  ("('NN', 'VBZ', 'RB', 'JJ', 'CC', 'JJ', '.')", 1167),
#  ("('JJ', 'NN', 'TO', 'VB', '.')", 1167)]

# %%
tag_dict["('JJ', 'NN', '.')"]
# Out:
# ['Comfortable bed .',
#  'Chic decorating .',
#  'Friendly staff .',
#  'Plush bedding .',
#  'Good location .',
#  'Comfortable bed .',
#  'Nice touch .',
#  'Wrong decision .',
#  'Nice touch .',
#  'Great layout .',
#  'Nice touch .',
#  'Clean room .',
#  'Enjoyable stay !',
#  'Wonderful service .',
#  'Great view .',
#  'Smooth check-in .',
#  'Great stay !',
#  'Nice staff .',
#  'Nice restaurant .',
#  'Nice room .',
#  'Nice staff .',
#  'Great view .',
#  'Nice touch !',
#  'Friendly service .',
#  'Great walk .',
#  'nice touch !',
#  'Excellent breakfast .',
#  'Friendly staff .',
#  'Nice touch .',
#  'Great staff .',
#  'Comfortable bed .',
#  'Wonderful staff .',
#  'Great experience .',
#  'decent size .',
#  'Top notch .',
#  'Awesome food .',
#  'Nice hotel .',
#  'Comfy bed .',
#  'Fantastic view .',
#  'Amazing hotel .',
#  'beautiful service .',
#  'great design !',
#  'great cocktail !',
#  'Outstanding neighborhood .',
#  'Peek-a-boo shower !',
#  'Great architecture .',
#  'Beautiful stay .',
#  'Great experience !',
#  'Beautiful view .',
#  'Bad idea .',
#  'Beautiful location .',
#  'Excellent presentation !',
#  'Great room !',
#  'Quality service !',
#  'Great coffee !',
#  'Big deal !',
#  'Good air-con .',
#  'Excellent hotel .',
#  'Great weekend !',
#  'Nice breakfast .',
#  'great hotel .',
#  'big room .',
#  'Clean bathroom .',
#  'Great value .',
#  'Nice place !',
#  'Quiet location .',
#  'Conflicted reviewer .',
#  'Small closet .',
#  'Great price !',
#  'Friendly staff .',
#  'Awesome food !',
#  'Friendly staff .',
#  'Excellent value .',
#  'Great service .',
#  'Good place .',
#  'Excellent Food !',
#  'Excellent service4 .',
#  'Friendly staff5 .',
#  'Excellent security .',
#  'Nice room .',
#  'Good breakfast .',
#  'Great personality !',
#  'Excellent Value !',
#  'Fantastic location .',
#  'Understated elegance .',
#  'Flawless choice .',
#  'Magnificent view .',
#  'Fantastic spa .',
#  'Nice touch .',
#  'Next visit !',
#  'Complementary breakfast .',
#  'Great service .',
#  'Separate toilet .',
#  'Good location .',
#  'Nice pool/gym .',
#  'Good service .',
#  'Good security .',
#  'Gracious hospitality .',
#  'Wonderful place !',
#  'great location !',
#  'Excellent value .',
#  'Comfortable experience .',
#  'Great shopping !',
#  'Friendly staff .',
#  'Lovely place !',
#  'nice place .',
#  'Beautiful place .',
#  'Amazing location .',
#  'Comfortable bed .',
#  'Good Price .',
#  'Total Nightmare .',
#  'Great staff .',
#  'Beautiful room .',
#  'Lovely hotel .',
#  'Terrible soundproofing .',
#  'Great place .',
#  'Great service !',
#  'Nice job !',
#  'Nice hotel !',
#  'Great Place .',
#  'Nice staff .',
#  'Excellent location .',
#  'Comfortable bed !',
#  'Wondeful job !',
#  'Incredible food .',
#  'Fancy lobby .',
#  'Excellent location .',
#  'Great restaurant !',
#  'Great staff .',
#  'Great room .',
#  'good lighting .',
#  'Great value .',
#  'Friendly staff .',
#  'Friendly staff .',
#  'great location !',
#  'Friendly staff .',
#  'Top location .',
#  'Huge disappointment .',
#  'Beautiful hotel .',
#  'Unbelievable place !',
#  'Excellent location .',
#  'Good location .',
#  'Fantastic quality .',
#  'Absolute bargain .',
#  'Fantastic hotel .',
#  'nIce pool .',
#  'Lovely Hotel .',
#  'Nice breakfast .',
#  'Small elevator .',
#  'Nice pool .',
#  'EXCEPTIONAL SERVICE !',
#  'Sluggish internet .',
#  'SUPERB room !',
#  'Great property !',
#  'Great room !',
#  'good breakfast !',
#  'Homely breakfast .',
#  'Next time .',
#  'Great beach .',
#  'Last tip .',
#  'Great staff .',
#  'Great pool .',
#  'GOOD LUCK !',
#  'Nice hotel .',
#  'old daughter .',
#  'Great bathroom .',
#  'Good luck .',
#  'Enjoy life !',
#  'Great job !',
#  'Lovely Fish !',
#  'Nice job .',
#  'Good luck !',
#  'good location .',
#  'comfortable bed .',
#  'Good parking .',
#  'Good location .',
#  'GREAT CHOICE !',
#  'Unbelievable choice .',
#  'free WiFi !',
#  'Outside temp .',
#  'Great service .',
#  'Quaint bar .',
#  'Excellent value .',
#  'Excellent jambalaya .',
#  'Excellent value .',
#  'Excellent Value !',
#  'nice decor .',
#  'Helpful staff .',
#  'Horrible experience !',
#  'Good staff .',
#  'Slow lift !',
#  'Great stay .',
#  'Brilliant location .',
#  'Helpful staff .',
#  'Friendly staff .',
#  'good rate .',
#  'Friendly staff .',
#  'Breathtaking place .',
#  'Fantastic palace !',
#  'Great stay .',
#  'great dj .',
#  'Great a/c .',
#  'Great fun !',
#  'GREAT STAFF .',
#  'Great staff !',
#  'Nice meal .',
#  'Nice breakfast .',
#  'Friendly staff .',
#  'Friendly staff .',
#  'peaceful location .',
#  'Great place .',
#  'Great Experience .',
#  'Great staff .',
#  'Excellent location .',
#  'Ample parking .',
#  'Great TV .',
#  'Great service !',
#  'Speedy check-in .',
#  'Nice pool .',
#  'Great value .',
#  'Old TV .',
#  'Big mistake .',
#  'Excellent stay .',
#  'Excellent hotel !',
#  'Filthy carpet .',
#  'Nice guy .',
#  'Lousy service .',
#  'AWFUL HOTEL !',
#  'Basic comfort .',
#  'Bad dream !',
#  'super bargain .',
#  'Double Yay !',
#  'Comfortable bed .',
#  'Excellent location !',
#  'Excellent service .',
#  'Nice atmosphere .',
#  'Lovely location .',
#  'Good all-around .',
#  'Expensive breakfast .',
#  'Excellent concierge .',
#  'Good value .',
#  'Excellent service .',
#  'awesome service .',
#  'Nice hotel .',
#  'Impeccable service .',
#  'Brilliant value .',
#  'Powerful shower .',
#  'Comfortable stay .',
#  'Solid hotel .',
#  'great location !',
#  'Great closet !',
#  'Decent hotel .',
#  'Terrible room.Dirty .',
#  'Good food .',
#  'Nice staff .',
#  'Great scenery .',
#  'Good job .',
#  'Disastrous management .',
#  'Great city .',
#  'Clean bathroom .',
#  'Excellent staff .',
#  'Incredible Staff .',
#  'Good breakfast .',
#  'Great value !',
#  'Great service .',
#  'Excellent value .',
#  'WONDERFUL LOCATION .',
#  'Great experience .',
#  'Great breakfast .',
#  'Nice policy .',
#  'Fantastic place .',
#  'Wonderful Experience !',
#  'Awesome vacation !',
#  'Great place !',
#  'Nice breeze !',
#  'Great resort !',
#  'Excellent breakfast .',
#  'Awful place .',
#  'Good service .',
#  'great room .',
#  'TERRIBLE EXPERIENCE !',
#  'Pure bliss !',
#  'Great staff .',
#  'Great bakery .',
#  'Friendly staff .',
#  'Twin bedroom .',
#  'Good location .',
#  'First thing .',
#  'Big mistake !',
#  'Lumpy bed .',
#  'Lovely hotel .',
#  'luxurious hotel !',
#  'decent suite .',
#  'Great service .',
#  'Nice touch .',
#  'GREAT EXPERIENCE !',
#  'GREAT experience !',
#  'Great staff !',
#  'Nice hotel !',
#  'Excellent service .',
#  'Great vacation !',
#  'Excellent service .',
#  'Outstanding service .',
#  'Good luck !',
#  'Great pool .',
#  'Lovely architecture .',
#  'Great night .',
#  'Small refrigerator .',
#  'GREAT SERVICE !',
#  'Excellent hotel .',
#  'Attentive staff .',
#  'Magnificent resort .',
#  'Great day .',
#  'high tech .',
#  'Decent breakfast .',
#  'Helpful staff .',
#  'Good Hotel .',
#  'Good room .',
#  'Good Food .',
#  'Great staff .',
#  'Friendly staff .',
#  'Welcoming environment .',
#  'Beautiful breakfast .',
#  'Wonderful hotel .',
#  'Nice staff .',
#  'Excellent value .',
#  'Great price .',
#  'Wonderful stay .',
#  'Excellent value .',
#  'Brilliant hotel .',
#  'central heat/air .',
#  'Excellent location .',
#  'Last yr .',
#  'Big deal !',
#  'Great breakfast .',
#  'Good breakfast .',
#  'great location .',
#  'Great team .',
#  'Wonderful service .',
#  'Great staff !',
#  'Horrible hotel .',
#  'Great breakfast .',
#  'Great staff !',
#  'Friendly staff .',
#  'Excellent treatment .',
#  'great atmosphere .',
#  'Quiet room .',
#  'Nice move .',
#  'Good hotel .',
#  'Nice atmosphere .',
#  'Great place .',
#  'Good location .',
#  'Great place .',
#  'Efficient restaurant .',
#  'Excellent hotel .',
#  'Such courtesy !',
#  'Great breakfast .',
#  'Beautiful hotel .',
#  'Friendly staff .',
#  'Beautiful resort .',
#  'Outstanding staff .',
#  'Beautiful resort .',
#  'Spectacular room .',
#  'Good value .',
#  'Awesome place .',
#  'Nice facility .',
#  'Beautiful resort .',
#  'Excellent staff .',
#  'Great stay !',
#  'Uncomfortable bed .',
#  'Attentive service .',
#  'Great pool .',
#  'Good choice .',
#  'Excellent experience .',
#  'Beautiful area .',
#  'Next time !',
#  'huge bummer .',
#  'Limited menu .',
#  'Great Decision !',
#  'Cute room .',
#  'Dirty DIRT .',
#  'Absolute heaven !',
#  'Lovely staff .',
#  'Fantastic hotel .',
#  'Nice resort .',
#  'Fantastic Place !',
#  'Beautiful resort .',
#  'Excellent pool .',
#  'HELLO paradise .',
#  'Fantastic vacation !',
#  'Total relaxation !',
#  'Great vacation !',
#  'Beautiful getaway !',
#  'Good place .',
#  'Good price .',
#  'Great value .',
#  'Good hotel .',
#  'Nice room .',
#  'Top quality .',
#  'Dowdy lobby .',
#  'New ownership ?',
#  'Amazing trip !',
#  'Definite disappointment .',
#  'Nonexistent security .',
#  'Amazing location !',
#  'Wonderful hotel .',
#  'So-So Hotel .',
#  'Pre-programmed trouble .',
#  'Good location .',
#  'Excellent value !',
#  'Nice bar .',
#  'Built-in armor .',
#  'Excellent hotel .',
#  'Wonderful bathroom !',
#  'Excellent value !',
#  'Friendly staff .',
#  'Great library/lounge .',
#  'Great neighborhood .',
#  'Much romance .',
#  'Nice courtyard .',
#  'free laundry .',
#  'Good luck .',
#  'Great value !',
#  'WRONG INFORMATION !',
#  'Horrible operation .',
#  'Nice balcony .',
#  'Helpful staff .',
#  'Nice hotel .',
#  'Good luck .',
#  'Great place !',
#  'Quirky hotel .',
#  'Friendly staff .',
#  'Excellent location .',
#  'Comfortable place .',
#  'Good value .',
#  'good pool .',
#  'lively pub .',
#  'Want juice ?',
#  'Nice breakfast .',
#  'Friendly staff .',
#  'Good breakfast .',
#  'Courteous staff .',
#  'Good-sized room .',
#  'Excellent hotel .',
#  'Good choice .',
#  'Decent neighborhood .',
#  'Good location .',
#  'Comfortable bed .',
#  'Great experience .',
#  'Excellent motel .',
#  'Good location .',
#  'Excellent hotel .',
#  'Big mistake !',
#  'Great experience !',
#  'lovely hotel .',
#  'great value .',
#  'good position .',
#  'Hidden Gem !',
#  'well-kept secret !',
#  'Plain Fun .',
#  'Good security .',
#  'Excellent location !',
#  'Friendly Staff .',
#  'Impeccable experience .',
#  'Fantastic service .',
#  'Beautiful hotel .',
#  'Wonderful staff .',
#  'Amazing place .',
#  'Amazing restaurant .',
#  'Amazing service .',
#  'Excellent location .',
#  'Friendly place .',
#  'Awesome coffee !',
#  'Unexpected pleasure .',
#  'Great experience .',
#  'Good breakfast .',
#  'Friendly staff .',
#  'Big deal .',
#  'Great experience .',
#  'Friendly staff .',
#  'Good job !',
#  'great location .',
#  'Tropical paradise !',
#  'Clean carpet .',
#  'Decent breakfast .',
#  'HUGE ROOM !',
#  'GREAT value !',
#  'Friendly staff .',
#  'Great service !',
#  'Nice location .',
#  'final comment .',
#  'Classy guy .',
#  'Wonderful Hotel .',
#  'Loud AC .',
#  'Nice sized-shower .',
#  'Reasonable price .',
#  'Nice casino .',
#  'Spacious room .',
#  'Great service .',
#  'Unpleasant experience .',
#  'Good deal .',
#  'excellent deal .',
#  'Interesting set-up !',
#  'Friendly staff .',
#  'Clean room .',
#  'Nice bathroom .',
#  'Spacious washroom .',
#  'Decent speed .',
#  'Big bathroom .',
#  'Outstanding hotel .',
#  'Good location .',
#  'Nice pool .',
#  'Great place !',
#  'Tebrik ederim .',
#  'Friendly staff .',
#  'Friendly staff .',
#  'Excellent shower .',
#  'Nice decor .',
#  'Great staff .',
#  'Awesome design .',
#  'Excellent location .',
#  'Nice landscaping .',
#  'Great place !',
#  'awesome food !',
#  'Friendly staff .',
#  'Spacious room .',
#  'Friendly staff .',
#  'Great experience !',
#  'GREAT location !',
#  'Nice hotel .',
#  'Comfortable bed .',
#  'unhelpful staff .',
#  'bad management .',
#  'Clean bathroom .',
#  'Good breakfast .',
#  'Fantastic location .',
#  'Fantastic location .',
#  'Excellent food .',
#  'Helpful staff .',
#  'Nice stay .',
#  'Superb service .',
#  'great location .',
#  'Awesome experience !',
#  'Beautiful place !',
#  'awesome hotel .',
#  'awesome staff .',
#  'Full kitchen .',
#  'Great value .',
#  'Beautiful view .',
#  'Horrible service .',
#  'Good location .',
#  'Excellent service .',
#  'Top notch !',
#  'Small pool .',
#  'Nice location .',
#  'Comfortable suite .',
#  'Excellent seafood .',
#  'Good location .',
#  'Excellent service .',
#  'Good Breakfast .',
#  'Friendly staff .',
#  'Friendly staff .',
#  'Nice touch .',
#  'Friendly staff .',
#  'Spacious bathroom .',
#  'Friendly staff .',
#  'Great breakfast .',
#  'Excellent service .',
#  'Good internet .',
#  'Lovely balcony .',
#  'Nice breakfast .',
#  'Excellent price/value .',
#  'Clean room .',
#  'Good breakfast .',
#  'Great breakfast .',
#  'Good choice !',
#  'Expensive breakfast .',
#  'Interesting haan .',
#  'free internet .',
#  'Helpful staff .',
#  'Classy stuff .',
#  'Fantastic lobby .',
#  'Great service .',
#  'Great price .',
#  'Good food .',
#  'Amazing place .',
#  'Amazing Service .',
#  'Amazing food .',
#  'AWESOME experience .',
#  'Quiet beach .',
#  'Great place .',
#  'Expensive camping .',
#  'Great sand .',
#  'Spacious porch .',
#  'Good luck !',
#  'Beautiful sand .',
#  'Beautiful beach !',
#  'Fantastic Hotel !',
#  'Fantastic Hotel .',
#  'Great stay !',
#  'Beautiful scenery .',
#  'Terible staff .',
#  'Nice suite .',
#  'Beautiful course .',
#  'Excellent concierge .',
#  'Beautiful scenery .',
#  'Breathtaking scenery .',
#  'Excellent hotel .',
#  'Excellent service .',
#  'Amazing time .',
#  'Nice staff .',
#  'Nice bonus !',
#  'Terrible service .',
#  'Excellent lighting .',
#  'Comfy bed !',
#  'Dangerous distric .',
#  'Nice bed .',
#  'Wonderful surprise .',
#  'Top notch !',
#  'Nice gym .',
#  'Great breakfast .',
#  'Fantastic stay .',
#  'Great food .',
#  'Lovely hotel .',
#  'Great innovation !',
#  'Great food .',
#  'great jacuzzi .',
#  'Good Hotel .',
#  'Good room .',
#  'Good Food .',
#  'Great staff .',
#  'Friendly staff .',
#  'Welcoming environment .',
#  'Beautiful breakfast .',
#  'Wonderful hotel .',
#  'Nice staff .',
#  'Excellent value .',
#  'Great price .',
#  'Wonderful stay .',
#  'Excellent value .',
#  'Brilliant hotel .',
#  'central heat/air .',
#  'Excellent location .',
#  'Last yr .',
#  'Big deal !',
#  'Great breakfast .',
#  'Great service .',
#  'Tasty food .',
#  'faultless experience .',
#  'Excellent service .',
#  'Acceptable speed .',
#  'Nice food .',
#  'Good location .',
#  'Excellent hotel !',
#  'Good Hotel .',
#  'unblocked view .',
#  'Good Hotel .',
#  'Good Hotel .',
#  'great place !',
#  'great location .',
#  'Constant attention .',
#  'Excellent service .',
#  'Great service .',
#  'Holy Cow !',
#  'spectacular service .',
#  'Elegant hotel .',
#  'Nice touch !',
#  'Excellent service .',
#  'Good deal .',
#  'fab hotel .',
#  'Nice touch .',
#  'Next time .',
#  'Great service !',
#  'Excellent location .',
#  'Huge bathroom .',
#  'Large bar/resteraunt .',
#  'Nice hotel .',
#  'Good location .',
#  'Miserable experience .',
#  'Friendly staff .',
#  'Fantastic value !',
#  'Great room .',
#  'nice pool .',
#  'Excellent value .',
#  'Great guacamole .',
#  'Great shower !',
#  'Amazing hotel !',
#  'Satisfactory room .',
#  'Good visit .',
#  'Nice bathroom .',
#  'Comfortable bed .',
#  'Good stay .',
#  'clean room .',
#  'large room .',
#  'Fantastic location !',
#  'BAD DECISION !',
#  'Beautiful lobby .',
#  'great evening .',
#  'Nice touch .',
#  'Excellent hotel !',
#  'Beautiful hotel !',
#  'Great Place .',
#  'Friendly staff .',
#  'Uncomfortable bed .',
#  'Great service !',
#  'Casual luxe ?',
#  'Great service !',
#  'Amazing view !',
#  'Beautiful hotel .',
#  'Pure bliss .',
#  'Great property .',
#  'Awesome location .',
#  'Exceptional service .',
#  'Great stuff !',
#  'Comfy bed .',
#  'Excellent location .',
#  'Friendly staff .',
#  'Big mistake .',
#  'Brilliant hotel .',
#  'Friendly staff .',
#  'GREAT LOCATION !',
#  'GREAT FOOD !',
#  'Awesome view .',
#  'Small world .',
#  'Good location .',
#  'Good location .',
#  'Friendly staff .',
#  'average roomservice .',
#  'Good breakfast .',
#  'Great fun .',
#  'Good location .',
#  'Good food .',
#  'Adequate bathroom .',
#  'Excelent hotel !',
#  'Great job !',
#  'good location .',
#  'Big mistake .',
#  'Great price !',
#  'Great idea .',
#  'Comfy bed .',
#  'Comfy bed .',
#  'Terrible experience .',
#  'Comfortable bed .',
#  'Beautiful breakfast .',
#  'Great Property .',
#  'Beautiful resort .',
#  'Awesome feature .',
#  'Great resort !',
#  'Awesome hotel !',
#  'Great spa .',
#  'Decent gym .',
#  'Incredible hotel !',
#  'Great service !',
#  'nice hotel .',
#  'good food .',
#  'complimentary shuttle .',
#  'great toilet !',
#  'Clean hotel .',
#  'Good value .',
#  'Hard Work .',
#  'Attentive staff .',
#  'Friendly staff .',
#  'Beautiful room .',
#  'Excellent location .',
#  'good location .',
#  'comfy bed .',
#  'Complimentary water ?',
#  'Luxurious bathroom .',
#  'Nice ride .',
#  'Wonderful staff .',
#  'Wonderful hotel !',
#  'Horrible food !',
#  'Great service .',
#  'Wonderful stay .',
#  '23rd floor .',
#  'Great lighting .',
#  'Great view !',
#  'Spectacular hotel .',
#  'Great stay .',
#  'Bad Idea !',
#  'Excelent location .',
#  'Lovely Hotel .',
#  'Great compensation !',
#  'Comfortable bed .',
#  'Friendly service .',
#  'Good service .',
#  'Good price .',
#  'Good hotel .',
#  'Cool place .',
#  'Good stuff .',
#  'Good breakfast .',
#  'Huge room .',
#  'Great bathroom .',
#  'Big TV .',
#  'Excellent service .',
#  'Quiet street .',
#  'Convenient location .',
#  'great location .',
#  'Excellent service !',
#  'Clean accommodation .',
#  'Awesome location !',
#  'Expensive parking .',
#  'OK restaurant .',
#  'Average breakfast .',
#  'Friendly staff .',
#  'Incredible place .',
#  'Gorgeous beach .',
#  'Beautiful garden !',
#  'Good bathroom .',
#  'Excellent position .',
#  'Great stay .',
#  'Great service .',
#  'Lovely experience .',
#  'Lovely touch !',
#  'Lovely beach .',
#  'great location .',
#  'Same price !',
#  'Friendly Staff .',
#  'Nice hotel .',
#  'Big bed .',
#  'Top notch .',
#  'Lovely hotel .',
#  'Wonderful pool .',
#  'Good price .',
#  'Great food .',
#  'Great atmosphere .',
#  'Friendly staff .',
#  'Nice stay !',
#  'Great maneger !',
#  'Nice pool .',
#  'Big disappointment .',
#  'Great breakfast .',
#  'Nice hotel .',
#  'Beautiful pool .',
#  'Good location .',
#  'Friendly staff .',
#  'Good shower .',
#  'Nice hotel .',
#  'Great place !',
#  'Great staff !',
#  'Big mistake .',
#  'GREAT FOOD !',
#  'Helpful staff .',
#  'Loud AC .',
#  'Beautiful pool .',
#  'Unprofessional business/staff .',
#  'HUGE disapointment .',
#  'Reasonable price .',
#  'Good selection .',
#  'Hot tub .',
#  'Nice touch !',
#  'Great place !',
#  'Spacious room .',
#  'Friendly staff .',
#  'Great Place .',
#  'Cozy fireplace .',
#  'Big room .',
#  'HOT coffee .',
#  'Excellent breakfast .',
#  'Excellent stay !',
#  'Beautiful location .',
#  'Helpful staff .',
#  'Decent space .',
#  'Good cleanliness .',
#  'Nice sight .',
#  'Nice neighbourhood .',
#  'Smart guy !',
#  'Great trip !',
#  'Nice lobby .',
#  'Inconsiderate staff .',
#  'bad attitude .',
#  'Clean bathroom .',
#  'Great stay .',
#  'Friendly staff .',
#  'Good location .',
#  'Great fun .',
#  'nice touch .',
#  'Wonderful atmosphere .',
#  'Great place !',
#  'Excellent location .',
#  'Beatiful decor .',
#  'Great place .',
#  'Great value .',
#  'Nice location .',
#  'Nice feature .',
#  'Sparse staff .',
#  'Nice touch .',
#  'Solid place .',
#  'Nice room .',
#  'Happy Gambling !',
#  'Great price !',
#  'Great staff .',
#  'Funky stuff !',
#  'Unbelivable value !',
#  'Stuffy service .',
#  'Pure class .',
#  'Great bed .',
#  'Beautiful hotel .',
#  'Nice location .',
#  'Friendly staff .',
#  'Friendly staff .',
#  'Good shower .',
#  'Great deal !',
#  'Good value .',
#  'Clean room .',
#  'Good parking .',
#  'Fantastic location .',
#  'Noisy AC .',
#  'Excellent value !',
#  'Fast internet .',
#  'Great stay .',
#  'Fantastic service .',
#  'Nice touch .',
#  'Excellent hotel .',
#  'Amazing memory !',
#  'Top notch !',
#  'FREE WIFI !',
#  'Great value .',
#  'Large pool .',
#  'large closet .',
#  'Great deal !',
#  'Weird layout .',
#  'Creepy shower .',
#  'Great value !',
#  'Top place !',
#  'Horrible Management !',
#  'awesome place .',
#  'Excellent staff .',
#  'Mediocre hotel .',
#  'Horrible management !',
#  'Clean room .',
#  'Clean bathroom .',
#  'Friendly staff .',
#  'Wonderful management .',
#  'Nice place .',
#  'Nice room .',
#  'Nice hotel .',
#  'Expensive parking .',
#  'Friendly staff .',
#  'Excellent choice .',
#  'Excellent location .',
#  'Nice breakfast .',
#  'great service .',
#  'Great service .',
#  'nice staff .',
#  'Nice bar/bistro .',
#  'Slow service .',
#  'Fantastic Resturant .',
#  'Wonderful comfort .',
#  'Non-smoking hotel .',
#  'Nice bar .',
#  'Excellent service .',
#  'Friendly staff .',
#  'Excellent stuff .',
#  'Wonderful place .',
#  'expensive breakfast .',
#  'Clean room .',
#  'Great view !',
#  'Nice price .',
#  'Good breakfast .',
#  'Geat value !',
#  'Excellent hotel .',
#  'Excellent location .',
#  'Great view .',
#  'Great HOTEL .',
#  'Stingy feeling .',
#  'Excellent breakfast !',
#  'Excellent food .',
#  'Nice hotel .',
#  'Excellent service .',
#  'Nice breakfast .',
#  'French cuisine !',
#  'Reasonable price .',
#  'Nice breakfast .',
#  'Nice staff .',
#  'Nice staff .',
#  'Great bunch .',
#  'Beautiful property .',
#  'Beautiful hotel !',
#  'Beautiful location .',
#  'Great experience .',
#  'Friendly staff .',
#  'Good location .',
#  'Great bargain .',
#  'Fantastic gym .',
#  'Beautiful view .',
#  'Huge hotel .',
#  'Great service .',
#  'Same attitude .',
#  'Great place .',
#  'Nice touch .',
#  'GREAT DEAL .',
#  'Second visit .',
#  'perfect location .',
#  'Excellant breakfast .',
#  'Small TV .',
#  'Excellent location .',
#  'Good location .',
#  'Excellent staff .',
#  'Excellent location .',
#  ...]

# %%
interest_anpos = [("('DT', 'NN', 'VBD', 'JJ', '.')", (1, 3)),   
                  ("('JJ', 'NN', '.')", (1, 0)),
                  ("('DT', 'NN', 'VBZ', 'JJ', '.')", (1, 3)),
                  ("('DT', 'NN', 'VBD', 'RB', 'JJ', '.')", (1, 4)),
                  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", (1, [3, 5])),
                  ("('NN', 'VBD', 'JJ', '.')", (0, 2)),
                  ("('DT', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", (1, [4, 6])),
                  ("('DT', 'NN', 'VBZ', 'RB', 'JJ', '.')", (1, 4)),
                  ("('PRP', 'VBD', 'DT', 'JJ', 'NN', '.')", (4, 3)),
                  ("('RB', 'JJ', 'NN', '.')", (2, 1)),
                  ("('NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", (0, [2, 4])),
                  ("('DT', 'NNS', 'VBD', 'JJ', '.')", (1, 3)),
                  ("('NN', 'VBD', 'RB', 'JJ', '.')", (0, 3))]

# %%
from collections import Counter

def write_csv_lines(filename, data):
    with open(filename, "w") as f:
        csvwriter = csv.writer(f)
        for line in data:
            csvwriter.writerow(line)
            
def location(tokens, loc):
    d = []
    if type(loc) is tuple:
        tok = [wd for wd in tokens[loc[0]:loc[1]+1] if re.sub(r'[^0-9a-zA-Z ]+', '', wd).isalnum()]
        if len(tok) > 0:
            d.append(" ".join(tok))
    elif type(loc) is list:
        tok = [tokens[l] for l in loc if re.sub(r'[^0-9a-zA-Z ]+', '', tokens[l]).isalnum()]
        if len(tok) > 0:
            d.extend(tok)
    else:
        if re.sub(r'[^0-9a-zA-Z ]+', '', tokens[loc]).isalnum():
            d.append(tokens[loc])
    return d


def extract_jj_nn(interest_anpos, tag_dict):
    noun_dict = Counter()
    adj_dict = Counter()
    for anpos in interest_anpos:
        pos, loc = anpos
        nloc, aloc = loc
        for sent in tag_dict[pos]:
            tokens = sent.lower().split()
            nouns = location(tokens, nloc)
#             if "one" in nouns:
#                 print(pos)
#                 print(sent)
            noun_dict.update(nouns)
            adjs = location(tokens, aloc)
            adj_dict.update(adjs)
    write_csv_lines("/media/data/hotels/kdd11/processed/extracted_tag/tag_aspects.csv", noun_dict.most_common())
    return noun_dict, adj_dict

# %%
tag_count.most_common(200)[0:20]
# Out:
# [("('DT', 'NN', 'VBD', 'JJ', '.')", 50288),
#  ("('JJ', 'NN', '.')", 41154),
#  ("('DT', 'NN', 'VBZ', 'JJ', '.')", 26655),
#  ("('DT', 'NN', 'VBD', 'RB', 'JJ', '.')", 25429),
#  ("('RB', 'JJ', '.')", 23816),
#  ("('PRP', 'MD', 'RB', 'VB', 'RB', 'RB', '.')", 20121),
#  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 19334),
#  ("('NN', 'VBD', 'JJ', '.')", 18287),
#  ("('DT', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", 16219),
#  ("('PRP', 'VBD', 'JJ', '.')", 14865),
#  ("('PRP', 'VBD', 'RB', 'JJ', '.')", 12688),
#  ("('DT', 'NN', 'VBZ', 'RB', 'JJ', '.')", 12038),
#  ("('PRP', 'VBD', 'DT', 'JJ', 'NN', '.')", 11414),
#  ("('RB', 'JJ', 'NN', '.')", 11025),
#  ("('NNP', 'NN', '.')", 10548),
#  ("('PRP', 'MD', 'VB', 'RB', 'RB', '.')", 9722),
#  ("('NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", 9525),
#  ("('DT', 'NNS', 'VBD', 'JJ', '.')", 9111),
#  ("('NN', 'VBD', 'RB', 'JJ', '.')", 9045),
#  ("('RB', 'VBN', '.')", 8130)]

# %%
tag_dict["('RB', 'JJ', 'NN', '.')"][0]
# Out:
# 'Extremely great value .'

# %%
interest_anpos = [
                  ("('DT', 'NN', 'VBD', 'JJ', '.')", (1, 3)),   
                  ("('DT', 'NN', 'VBZ', 'JJ', '.')", (1, 3)),
                  ("('DT', 'NN', 'VBD', 'RB', 'JJ', '.')", (1, 4)),
                  ("('DT', 'NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", (1, [3, 5])),
                  ("('NN', 'VBD', 'JJ', '.')", (0, 2)),
                  ("('DT', 'NN', 'VBD', 'RB', 'JJ', 'CC', 'JJ', '.')", (1, [4, 6])),
                  ("('DT', 'NN', 'VBZ', 'RB', 'JJ', '.')", (1, 4)),
                  ("('PRP', 'VBD', 'DT', 'JJ', 'NN', '.')", (4, 3)),
                  ("('RB', 'JJ', 'NN', '.')", (2, 1)),
#                   ("('NN', 'VBD', 'JJ', 'CC', 'JJ', '.')", (0, [2, 4])),
#                   ("('DT', 'NNS', 'VBD', 'JJ', '.')", (1, 3)),
#                   ("('NN', 'VBD', 'RB', 'JJ', '.')", (0, 3)),
                  ("('DT', 'NN', 'NN', 'VBD', 'JJ', '.')", ((1,2), 4)),
                 ("('DT', 'NN', 'IN', 'DT', 'NN', 'VBD', 'JJ', '.')", (1, 6))
                 ]


noun_dict, adj_dict = extract_jj_nn(interest_anpos, tag_dict)

# %%
noun_dict.most_common(10)
# Out:
# [('staff', 31787),
#  ('room', 20750),
#  ('hotel', 15178),
#  ('location', 14115),
#  ('bed', 6784),
#  ('service', 6513),
#  ('bathroom', 5976),
#  ('food', 5411),
#  ('breakfast', 4526),
#  ('place', 3626)]

# %%
def read_csv(fname):
    data = []
    with open(fname, "r") as f:
        csvreader = csv.reader(f)
        for line in csvreader:
            data.append(line)
    return data

# %%
pos_data = read_csv(pos_file)
sbut_clauses = [line[0] for line in pos_data if re.match(r"but", line[0])]
ibut_clauses = [line[0] for line in pos_data if not re.match(r"but", line[0]) and line[1]=="but"]
